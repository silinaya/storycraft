# %%
PROJECT_ID = "svc-demo-vertex"
REGION = "us-central1"
BUCKET_NAME = "gs://svc-demo-vertex-us"
SERVICE="storycraft"

# %%
# Set the IMAGE_URI
IMAGE_URI=f"us-central1-docker.pkg.dev/{PROJECT_ID}/vertexai/{SERVICE}:v1"

# %%
! docker build -f ./Dockerfile -t $IMAGE_URI .
# Out:
# Sending build context to Docker daemon  7.054MB
# Step 1/30 : FROM node:23-alpine AS base
#  ---> 31d93c95bd30
# Step 2/30 : FROM base AS deps
#  ---> 31d93c95bd30
# Step 3/30 : RUN apk add --update libc6-compat
#  ---> Using cache
#  ---> 987e3ba7541d
# Step 4/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> aee0a0cdc1ac
# Step 5/30 : WORKDIR /app
#  ---> Using cache
#  ---> fcf22aff8751
# Step 6/30 : COPY package.json yarn.lock* package-lock.json* pnpm-lock.yaml* ./
#  ---> Using cache
#  ---> 173c545d6ff4
# Step 7/30 : RUN   if [ -f yarn.lock ]; then yarn --frozen-lockfile;   elif [ -f package-lock.json ]; then npm ci;   elif [ -f pnpm-lock.yaml ]; then yarn global add pnpm && pnpm i --frozen-lockfile;   else echo "Lockfile not found." && exit 1;   fi
#  ---> Using cache
#  ---> 630a30856fa0
# Step 8/30 : FROM base AS builder
#  ---> 31d93c95bd30
# Step 9/30 : WORKDIR /app
#  ---> Using cache
#  ---> 78cd07260f56
# Step 10/30 : COPY --from=deps /app/node_modules ./node_modules
#  ---> Using cache
#  ---> 0d8bb4440234
# Step 11/30 : COPY . .
#  ---> 3d564a843bdb
# Step 12/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Running in e740a5921de4
# Removing intermediate container e740a5921de4
#  ---> 6a7938528e6e
# Step 13/30 : RUN yarn build
#  ---> Running in 7e4ea256f575
# yarn run v1.22.22
# $ next build
#   ▲ Next.js 14.2.16
#
#    Creating an optimized production build ...
# (node:40) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:78) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#  ✓ Compiled successfully
#    Linting and checking validity of types ...
#    Collecting page data ...
# (node:130) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#    Generating static pages (0/7) ...
#    Generating static pages (1/7)
#    Generating static pages (3/7)
#    Generating static pages (5/7)
# (node:131) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# Component rendered
#  ✓ Generating static pages (7/7)
#    Finalizing page optimization ...
#    Collecting build traces ...
#
# Route (app)                              Size     First Load JS
# ┌ ○ /                                    65.3 kB         152 kB
# ├ ○ /_not-found                          873 B            88 kB
# ├ ƒ /api/scene                           0 B                0 B
# └ ƒ /api/videos                          0 B                0 B
# + First Load JS shared by all            87.1 kB
#   ├ chunks/117-a6603f03b208d3bf.js       31.6 kB
#   ├ chunks/fd9d1056-796f5f0836d7e441.js  53.6 kB
#   └ other shared chunks (total)          1.9 kB
#
#
# ○  (Static)   prerendered as static content
# ƒ  (Dynamic)  server-rendered on demand
#
# Done in 75.76s.
# Removing intermediate container 7e4ea256f575
#  ---> eef80b34a371
# Step 14/30 : FROM base AS runner
#  ---> 31d93c95bd30
# Step 15/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> 449c1d6b227f
# Step 16/30 : WORKDIR /app
#  ---> Using cache
#  ---> a00de02aa310
# Step 17/30 : ENV NODE_ENV production
#  ---> Using cache
#  ---> 71df020a905a
# Step 18/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Using cache
#  ---> d2b2ef033973
# Step 19/30 : RUN addgroup --system --gid 1001 nodejs
#  ---> Using cache
#  ---> 398182075167
# Step 20/30 : RUN adduser --system --uid 1001 nextjs
#  ---> Using cache
#  ---> 599cdbe83371
# Step 21/30 : COPY --from=builder /app/public ./public
#  ---> Using cache
#  ---> 6f3b2cd7868d
# Step 22/30 : RUN mkdir .next
#  ---> Using cache
#  ---> f048399198df
# Step 23/30 : RUN chown nextjs:nodejs .next
#  ---> Using cache
#  ---> bf120094df46
# Step 24/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/standalone ./
#  ---> aded81401f91
# Step 25/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/static ./.next/static
#  ---> 57cee7de9646
# Step 26/30 : USER nextjs
#  ---> Running in dc4048e4fb3c
# Removing intermediate container dc4048e4fb3c
#  ---> 150bdaf99d70
# Step 27/30 : EXPOSE 3000
#  ---> Running in e80a6d431b3e
# Removing intermediate container e80a6d431b3e
#  ---> 7211d1e959bb
# Step 28/30 : ENV PORT 3000
#  ---> Running in 3dd4fe84041c
# Removing intermediate container 3dd4fe84041c
#  ---> 3d278c00b710
# Step 29/30 : ENV HOSTNAME "0.0.0.0"
#  ---> Running in b3d0873c8f59
# Removing intermediate container b3d0873c8f59
#  ---> 1158cf911422
# Step 30/30 : CMD ["node", "server.js"]
#  ---> Running in 18c18efc07e6
# Removing intermediate container 18c18efc07e6
#  ---> 2418c838f7ad
# Successfully built 2418c838f7ad
# Successfully tagged us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft:v1

# %%
! docker push $IMAGE_URI
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft]
#
# 5ecd24af: Preparing
# e8fcb7d8: Preparing
# 642e6ad4: Preparing
# 86412661: Preparing
# 67124216: Preparing
# 78baf38f: Preparing
# 3ef1be29: Preparing
# c3228a59: Preparing
# fa0ec069: Preparing
# 1c5999de: Preparing
# 64ef9611: Preparing
# 842cb1dd: Preparing
# 8fcb7d8: Pushed   57.68MB/56.09MBv1: digest: sha256:7a166dd7b94480560b1f2801142fe727244f16a538d3e386d51e495c5a2be6ab size: 3039

# %%
# %%capture capt
! gcloud run deploy $SERVICE --image $IMAGE_URI --region $REGION --cpu 2

# %%
print(capt.stderr)

# %%
! gcloud beta run services logs tail $SERVICE --project $PROJECT_ID --region $REGION
# Out:
# streaming logs from svc-demo-vertex
# 2025-01-29 22:32:19 GET 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-29 22:32:19  ✓ Ready in 8s
# 2025-01-29 22:32:20 GET 200 https://storycraft-125188993477.us-central1.run.app/favicon.ico
# 2025-01-29 22:32:34 Create a storyboard
# 2025-01-29 22:32:34 (node:1) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# 2025-01-29 22:32:34 (Use `node --trace-deprecation ...` to show where the warning was created)
# 2025-01-29 22:32:50 A seasoned snowboarder, known for his daring tricks, faces a young, ambitious rival at the Winter X-Games. The veteran, haunted by a past injury, must overcome his fear and push his limits to reclaim his title, while the newcomer is determined to make his mark. Their rivalry culminates in a final, breathtaking run down a treacherous, snow-covered mountain.
# 2025-01-29 22:32:50 [
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     name: 'Jax',
# 2025-01-29 22:32:50     description: 'A weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze. He wears a dark grey snowboarding jacket, black pants, and a red helmet.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     name: 'Kai',
# 2025-01-29 22:32:50     description: 'A lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes. He wears a bright blue snowboarding jacket, white pants, and a white helmet.'
# 2025-01-29 22:32:50   }
# 2025-01-29 22:32:50 ]
# 2025-01-29 22:32:50 [
# 2025-01-29 22:32:50   'The Base Camp, a bustling area with snow-covered tents, equipment, and a large screen displaying the competition scores.',
# 2025-01-29 22:32:50   'The Slopestyle Course, a challenging course with various ramps, rails, and jumps, all covered in snow.',
# 2025-01-29 22:32:50   'The Mountain Peak, a high, snow-covered peak with a steep slope, where the final run takes place.'
# 2025-01-29 22:32:50 ]
# 2025-01-29 22:32:50 [
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, standing alone at the base camp, with snow-covered tents and equipment in the background. A large screen displays competition scores.',
# 2025-01-29 22:32:50     videoPrompt: 'A slow zoom in on a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, as he adjusts his goggles, with snow-covered tents and equipment in the background. A large screen displays competition scores.',
# 2025-01-29 22:32:50     description: 'Jax stands alone at the base camp, observing the competition scores, a mix of determination and apprehension on his face.',
# 2025-01-29 22:32:50     voiceover: 'Jax felt the weight of his past.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, performing a complex trick on a rail at the slopestyle course. The course is covered in snow, with various ramps and jumps.',
# 2025-01-29 22:32:50     videoPrompt: 'A fast-paced shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, sliding down a rail, with snow spraying around him at the slopestyle course. The course is covered in snow, with various ramps and jumps.',
# 2025-01-29 22:32:50     description: 'Kai executes a flawless trick on the slopestyle course, showcasing his skill and confidence.',
# 2025-01-29 22:32:50     voiceover: 'Kai was the new force to be reckoned with.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, looking up at the mountain peak with a mix of fear and determination. The mountain peak is high and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A slow pan up from a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, to the mountain peak, which is high and snow-covered.',
# 2025-01-29 22:32:50     description: 'Jax gazes up at the mountain peak, his past injury flashing through his mind, but his determination remains.',
# 2025-01-29 22:32:50     voiceover: 'The mountain was a reminder of his fall.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, standing at the top of the mountain peak, ready to start his run. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A quick shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, adjusting his stance at the top of the mountain peak, ready to start his run. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     description: 'Kai stands at the top of the mountain, poised and ready for his final run.',
# 2025-01-29 22:32:50     voiceover: 'Kai was ready to claim his victory.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, speeding down the mountain peak, performing a daring jump. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A fast-paced shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, flying through the air after a jump, with snow spraying around him. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     description: 'Jax pushes his limits, executing a daring jump down the mountain, overcoming his fear.',
# 2025-01-29 22:32:50     voiceover: 'Jax had to push past his limits.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, closely following a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, down the mountain peak. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A dynamic shot of a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, chasing a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, down the mountain peak. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     description: 'Kai closely follows Jax, their rivalry intensifying as they race down the mountain.',
# 2025-01-29 22:32:50     voiceover: 'The race was on, neck and neck.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, landing a difficult trick on the mountain peak, with snow spraying around him. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A slow-motion shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, landing a difficult trick on the mountain peak, with snow spraying around him. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     description: 'Jax lands a difficult trick, showcasing his experience and skill.',
# 2025-01-29 22:32:50     voiceover: 'Jax showed his experience.'
# 2025-01-29 22:32:50   },
# 2025-01-29 22:32:50   {
# 2025-01-29 22:32:50     imagePrompt: 'A cinematic, photorealistic shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, crossing the finish line on the mountain peak, with a look of triumph and exhaustion. A lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, is seen in the background. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     videoPrompt: 'A wide shot of a weathered, 35-year-old male snowboarder with a rugged face, short, dark hair, and a determined gaze, wearing a dark grey snowboarding jacket, black pants, and a red helmet, crossing the finish line on the mountain peak, with a lean, 22-year-old male snowboarder with a confident smirk, light brown hair, and piercing blue eyes, wearing a bright blue snowboarding jacket, white pants, and a white helmet, slowing down in the background. The slope is steep and snow-covered.',
# 2025-01-29 22:32:50     description: 'Jax crosses the finish line, exhausted but triumphant, having overcome his fears and pushed his limits. Kai is seen in the background.',
# 2025-01-29 22:32:50     voiceover: 'Jax had won the day.'
# 2025-01-29 22:32:50   }
# 2025-01-29 22:32:50 ]
# 2025-01-29 22:32:50 Generating image for scene 1
# 2025-01-29 22:32:50 Generating image for scene 2
# 2025-01-29 22:32:50 Generating image for scene 3
# 2025-01-29 22:32:50 Generating image for scene 4
# 2025-01-29 22:32:50 Generating image for scene 5
# 2025-01-29 22:32:50 Generating image for scene 6
# 2025-01-29 22:32:50 Generating image for scene 7
# 2025-01-29 22:32:50 Generating image for scene 8
# 2025-01-29 22:32:54 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:32:34 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-29 22:33:51 Create a storyboard
# 2025-01-29 22:34:08 A seasoned snowboarder, known for his daring tricks, faces off against a rising star in a high-stakes, winner-takes-all competition at the X-Games. The competition takes place on a treacherous, custom-built course featuring massive jumps and icy rails. The veteran, fueled by experience and a desire to prove he's still at the top, clashes with the newcomer's raw talent and fearless approach. The narrative focuses on their intense rivalry and the breathtaking stunts they perform, culminating in a final, gravity-defying trick that determines the champion.
# 2025-01-29 22:34:08 [
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     name: 'Jax',
# 2025-01-29 22:34:08     description: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     name: 'Kai',
# 2025-01-29 22:34:08     description: 'A young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles.'
# 2025-01-29 22:34:08   }
# 2025-01-29 22:34:08 ]
# 2025-01-29 22:34:08 [
# 2025-01-29 22:34:08   'X-Games Course, a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky.',
# 2025-01-29 22:34:08   'Starting Gate, a raised platform at the top of the course where the snowboarders prepare for their runs.'
# 2025-01-29 22:34:08 ]
# 2025-01-29 22:34:08 [
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: "A cinematic, photorealistic shot of a seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, standing at the starting gate of a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera angle is low, emphasizing the height of the course and the snowboarder's readiness.",
# 2025-01-29 22:34:08     videoPrompt: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, adjusts his stance on his snowboard at the starting gate. The camera slowly zooms in on his face, capturing his focused expression.',
# 2025-01-29 22:34:08     description: 'Jax stands at the starting gate, taking a deep breath before his run.',
# 2025-01-29 22:34:08     voiceover: 'Jax prepares for his final run.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: "A cinematic, photorealistic shot of a young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, launching off a massive jump on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is positioned mid-air, capturing the snowboarder's full extension and the vastness of the jump.",
# 2025-01-29 22:34:08     videoPrompt: 'A young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, executes a complex aerial trick, spinning and grabbing his board mid-air. The camera follows his movement smoothly.',
# 2025-01-29 22:34:08     description: 'Kai executes a flawless aerial trick, showcasing his raw talent.',
# 2025-01-29 22:34:08     voiceover: 'Kai shows off his incredible skill.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: 'A cinematic, photorealistic shot of a seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, grinding along an icy rail on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is at eye-level, emphasizing the speed and precision of the grind.',
# 2025-01-29 22:34:08     videoPrompt: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, maintains perfect balance while grinding along an icy rail. The camera tracks his movement smoothly, highlighting the sparks flying from his board.',
# 2025-01-29 22:34:08     description: 'Jax grinds a long, icy rail with incredible control.',
# 2025-01-29 22:34:08     voiceover: 'Jax shows his experience on the rail.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: 'A cinematic, photorealistic shot of a young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, landing a massive jump on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is positioned at ground level, capturing the impact of the landing and the spray of snow.',
# 2025-01-29 22:34:08     videoPrompt: 'A young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, lands a massive jump with a powerful thud, sending snow flying. The camera shakes slightly with the impact.',
# 2025-01-29 22:34:08     description: 'Kai lands a huge jump with a powerful impact.',
# 2025-01-29 22:34:08     voiceover: 'Kai sticks the landing perfectly.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: 'A cinematic, photorealistic shot of a seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, preparing for a final jump on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is a close-up, focusing on his determined expression.',
# 2025-01-29 22:34:08     videoPrompt: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, takes a deep breath and adjusts his goggles, preparing for his final trick. The camera slowly zooms in on his eyes.',
# 2025-01-29 22:34:08     description: 'Jax prepares for his final, high-stakes trick.',
# 2025-01-29 22:34:08     voiceover: 'Jax is ready to give it his all.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: "A cinematic, photorealistic shot of a seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, performing a complex, gravity-defying trick mid-air on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is positioned mid-air, capturing the full scope of the trick and the snowboarder's silhouette against the sky.",
# 2025-01-29 22:34:08     videoPrompt: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, executes a complex, never-before-seen trick, spinning and flipping in the air. The camera follows his movement smoothly, emphasizing the difficulty of the trick.',
# 2025-01-29 22:34:08     description: 'Jax executes a never-before-seen trick, pushing his limits.',
# 2025-01-29 22:34:08     voiceover: 'Jax attempts the impossible.'
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: "A cinematic, photorealistic shot of a young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, watching Jax's final trick from the bottom of the course on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is focused on his face, showing a mix of awe and respect.",
# 2025-01-29 22:34:08     videoPrompt: "A young, athletic snowboarder in his early 20s, with a clean-shaven face, light brown hair, and an intense, focused expression. He wears a bright blue and white snowsuit, a white helmet, and clear goggles, watches Jax's final trick with a mix of awe and respect. The camera slowly zooms in on his face, capturing his reaction.",
# 2025-01-29 22:34:08     description: "Kai watches Jax's final trick, impressed by his skill.",
# 2025-01-29 22:34:08     voiceover: "Kai is amazed by Jax's performance."
# 2025-01-29 22:34:08   },
# 2025-01-29 22:34:08   {
# 2025-01-29 22:34:08     imagePrompt: "A cinematic, photorealistic shot of a seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, landing his final trick with a triumphant pose on a custom-built snow park with massive jumps, icy rails, and a backdrop of snow-covered mountains under a clear, bright sky. The camera is at eye-level, capturing the snowboarder's victorious stance and the cheering crowd in the background.",
# 2025-01-29 22:34:08     videoPrompt: 'A seasoned snowboarder in his late 30s, with a weathered face, short, dark hair, and a determined gaze. He wears a black and grey snowsuit with sponsor logos, a black helmet, and mirrored goggles, lands his final trick perfectly and raises his arms in victory. The camera pans out to show the cheering crowd.',
# 2025-01-29 22:34:08     description: 'Jax lands his final trick, victorious and triumphant.',
# 2025-01-29 22:34:08     voiceover: 'Jax lands the trick and wins the competition.'
# 2025-01-29 22:34:08   }
# 2025-01-29 22:34:08 ]
# 2025-01-29 22:34:08 Generating image for scene 1
# 2025-01-29 22:34:08 Generating image for scene 2
# 2025-01-29 22:34:08 Generating image for scene 3
# 2025-01-29 22:34:08 Generating image for scene 4
# 2025-01-29 22:34:08 Generating image for scene 5
# 2025-01-29 22:34:08 Generating image for scene 6
# 2025-01-29 22:34:08 Generating image for scene 7
# 2025-01-29 22:34:08 Generating image for scene 8
# 2025-01-29 22:34:12 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:12 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:34:13 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-29 22:33:51 POST 200 https://storycraft-125188993477.us-central1.run.app/
