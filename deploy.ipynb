# %%
PROJECT_ID = "svc-demo-vertex"
REGION = "us-central1"
BUCKET_NAME = "gs://mb-cloud-llm-preview1-bucket/img2vid"
SERVICE="storycraft"

# %%
# Set the IMAGE_URI
IMAGE_URI=f"us-central1-docker.pkg.dev/{PROJECT_ID}/vertexai/{SERVICE}:v1"

# %%
! docker build -f ./Dockerfile -t $IMAGE_URI .

# %%
! docker push $IMAGE_URI

# %%
# %%capture capt
! gcloud run deploy $SERVICE --image $IMAGE_URI --region $REGION --set-env-vars PROJECT_ID="svc-demo-vertex",LOCATION="us-central1",MODEL="veo-2.0-generate-001",GCS_VIDEOS_STORAGE_URI="gs://svc-demo-vertex-us/storycraft/",USE_SIGNED_URL="true"

# %%
# print(capt.stderr)

# %%
! gcloud beta run services logs tail $SERVICE --project $PROJECT_ID --region $REGION
