# %%
PROJECT_ID = "svc-demo-vertex"
REGION = "us-central1"
BUCKET_NAME = "gs://svc-demo-vertex-us"
SERVICE="storycraft"

# %%
# Set the IMAGE_URI
IMAGE_URI=f"us-central1-docker.pkg.dev/{PROJECT_ID}/vertexai/{SERVICE}:v1"

# %%
! docker build -f ./Dockerfile -t $IMAGE_URI .
# Out:
# Sending build context to Docker daemon  4.211MB
# Step 1/30 : FROM node:23-alpine AS base
#  ---> 31d93c95bd30
# Step 2/30 : FROM base AS deps
#  ---> 31d93c95bd30
# Step 3/30 : RUN apk add --update libc6-compat
#  ---> Using cache
#  ---> 987e3ba7541d
# Step 4/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> aee0a0cdc1ac
# Step 5/30 : WORKDIR /app
#  ---> Using cache
#  ---> fcf22aff8751
# Step 6/30 : COPY package.json yarn.lock* package-lock.json* pnpm-lock.yaml* ./
#  ---> Using cache
#  ---> d5473487960d
# Step 7/30 : RUN   if [ -f yarn.lock ]; then yarn --frozen-lockfile;   elif [ -f package-lock.json ]; then npm ci;   elif [ -f pnpm-lock.yaml ]; then yarn global add pnpm && pnpm i --frozen-lockfile;   else echo "Lockfile not found." && exit 1;   fi
#  ---> Using cache
#  ---> 6f1c6f19890e
# Step 8/30 : FROM base AS builder
#  ---> 31d93c95bd30
# Step 9/30 : WORKDIR /app
#  ---> Using cache
#  ---> 78cd07260f56
# Step 10/30 : COPY --from=deps /app/node_modules ./node_modules
#  ---> Using cache
#  ---> 6fe85f33f931
# Step 11/30 : COPY . .
#  ---> 7e7d4c42dea0
# Step 12/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Running in 91b7fd0b1ba8
# Removing intermediate container 91b7fd0b1ba8
#  ---> fc0a38c210cb
# Step 13/30 : RUN yarn build
#  ---> Running in 3fa18a01a315
# yarn run v1.22.22
# $ next build
#   ▲ Next.js 14.2.16
#
#    Creating an optimized production build ...
# (node:40) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:78) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#  ✓ Compiled successfully
#    Linting and checking validity of types ...
#    Collecting page data ...
#    Generating static pages (0/5) ...
#    Generating static pages (1/5)
#    Generating static pages (2/5)
#    Generating static pages (3/5)
#  ✓ Generating static pages (5/5)
#    Finalizing page optimization ...
#    Collecting build traces ...
#
# Route (app)                              Size     First Load JS
# ┌ ○ /                                    64.2 kB         151 kB
# └ ○ /_not-found                          873 B            88 kB
# + First Load JS shared by all            87.1 kB
#   ├ chunks/117-a6603f03b208d3bf.js       31.6 kB
#   ├ chunks/fd9d1056-796f5f0836d7e441.js  53.6 kB
#   └ other shared chunks (total)          1.9 kB
#
#
# ○  (Static)  prerendered as static content
#
# Done in 65.22s.
# Removing intermediate container 3fa18a01a315
#  ---> 4b4810eff83b
# Step 14/30 : FROM base AS runner
#  ---> 31d93c95bd30
# Step 15/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> 449c1d6b227f
# Step 16/30 : WORKDIR /app
#  ---> Using cache
#  ---> a00de02aa310
# Step 17/30 : ENV NODE_ENV production
#  ---> Using cache
#  ---> 71df020a905a
# Step 18/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Using cache
#  ---> d2b2ef033973
# Step 19/30 : RUN addgroup --system --gid 1001 nodejs
#  ---> Using cache
#  ---> 398182075167
# Step 20/30 : RUN adduser --system --uid 1001 nextjs
#  ---> Using cache
#  ---> 599cdbe83371
# Step 21/30 : COPY --from=builder /app/public ./public
#  ---> Using cache
#  ---> 6a10cb44785c
# Step 22/30 : RUN mkdir .next
#  ---> Using cache
#  ---> 9373a8b0f231
# Step 23/30 : RUN chown nextjs:nodejs .next
#  ---> Using cache
#  ---> b0d533d272f8
# Step 24/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/standalone ./
#  ---> 6dce084c91da
# Step 25/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/static ./.next/static
#  ---> 481b34bd7a8b
# Step 26/30 : USER nextjs
#  ---> Running in 0170004af04a
# Removing intermediate container 0170004af04a
#  ---> 851f733986ba
# Step 27/30 : EXPOSE 3000
#  ---> Running in 47e899bffa77
# Removing intermediate container 47e899bffa77
#  ---> e447e18f473a
# Step 28/30 : ENV PORT 3000
#  ---> Running in c42b5206fde5
# Removing intermediate container c42b5206fde5
#  ---> 573b665612a7
# Step 29/30 : ENV HOSTNAME "0.0.0.0"
#  ---> Running in 8a8bd8205c17
# Removing intermediate container 8a8bd8205c17
#  ---> b232510f70c1
# Step 30/30 : CMD ["node", "server.js"]
#  ---> Running in cee0aad09402
# Removing intermediate container cee0aad09402
#  ---> 1625de09db57
# Successfully built 1625de09db57
# Successfully tagged us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft:v1

# %%
! docker push $IMAGE_URI
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft]
#
# dfb8f5db: Preparing
# 53b5a6d4: Preparing
# c5af5420: Preparing
# 21713859: Preparing
# b7cfd617: Preparing
# 78baf38f: Preparing
# 3ef1be29: Preparing
# c3228a59: Preparing
# fa0ec069: Preparing
# 1c5999de: Preparing
# 64ef9611: Preparing
# 842cb1dd: Preparing
# 3b5a6d4: Pushed   23.15MB/21.63MBv1: digest: sha256:019ba8e7ad7a83945514c0e7f046cb42af1a0ca3b2d2df9ee8f156eee538d056 size: 3038

# %%
! gcloud run deploy $SERVICE --image $IMAGE_URI --region $REGION
# Out:
# Deploying container to Cloud Run service [storycraft] in project [svc-demo-vertex] region [us-central1]
# Deploying...
#   . Creating Revision...
#   . Routing traffic...
#   Deploying...
#
#
# ⠛ Deploying...
#
#
# ⠹ Deploying...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
# ⠧ Deploying...
#   ⠧ Creating Revision...
#
# ⠏ Deploying... Deploying Revision.
#   ⠏ Creating Revision... Updating Service.
#
# ⠛ Deploying... Deploying Revision.
#   ⠛ Creating Revision... Updating Service.
#
# ⠹ Deploying... Deploying Revision.
#   ⠹ Creating Revision... Updating Service.
#
# ⠼ Deploying... Deploying Revision.
#   ⠼ Creating Revision... Updating Service.
#
# ⠶ Deploying... Deploying Revision.
#   ⠶ Creating Revision... Updating Service.
#
# ⠧ Deploying... Deploying Revision.
#   ⠧ Creating Revision... Updating Service.
#
# ⠏ Deploying... Deploying Revision.
#   ⠏ Creating Revision... Updating Service.
#
# ⠛ Deploying... Deploying Revision.
#   ⠛ Creating Revision... Updating Service.
#
# ⠹ Deploying... Deploying Revision.
#   ⠹ Creating Revision... Updating Service.
#
# ⠼ Deploying... Deploying Revision.
#   ⠼ Creating Revision... Updating Service.
#
# ⠶ Deploying... Deploying Revision.
#   ⠶ Creating Revision... Updating Service.
#
# ⠧ Deploying... Deploying Revision.
#   ⠧ Creating Revision... Updating Service.
#
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ⠏ Creating Revision... Updating Service.
#   ⠏ Routing traffic...
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ⠛ Creating Revision... Updating Service.
#   ⠛ Routing traffic...
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠹ Routing traffic...
# ⠼ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠶ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠧ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠹ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠼ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠶ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠧ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠹ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠼ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00045
#   -hvv.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.64s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Container became healthy in 2.23s.
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Container became healthy in 2.23s.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Container became healthy in 2.23s.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Container became healthy in 2.23s.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Container became healthy in 2.23s.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Container became healthy in 2.23s.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Container became healthy in 2.23s.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Container became healthy in 2.23s.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Container became healthy in 2.23s.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Container became healthy in 2.23s.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Container became healthy in 2.23s.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Container became healthy in 2.23s.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying...
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying...
#
#
#   ✓ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Done.
#
#
#
# ⠛ Deploying... Done.
#
#
#
# ⠹ Deploying... Done.
#
#
#
# ✓ Deploying... Done.
#
#
#
# Done.
# Service [storycraft] revision [storycraft-00045-hvv] has been deployed and is serving 100 percent of traffic.
# Service URL: https://storycraft-idvt3gzwzq-uc.a.run.app

# %%
! gcloud beta run services logs tail $SERVICE --project $PROJECT_ID --region $REGION
# Out:
# streaming logs from svc-demo-vertex
# 2025-01-23 21:52:50 GET 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:52:54 GET 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:52:54 GET 200 https://storycraft-125188993477.us-central1.run.app/_next/static/chunks/app/page-12030267cb7969b1.js
# 2025-01-23 21:52:54 GET 200 https://storycraft-125188993477.us-central1.run.app/_next/static/css/28095b0e2e55511f.css
# 2025-01-23 21:52:54 GET 200 https://storycraft-125188993477.us-central1.run.app/favicon.ico
# 2025-01-23 21:53:10 (node:1) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# 2025-01-23 21:53:10 (Use `node --trace-deprecation ...` to show where the warning was created)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 0)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 7)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 6)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 4)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 5)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 3)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 1)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:26 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:53:26     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:53:26     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:53:26     at async Promise.all (index 2)
# 2025-01-23 21:53:26     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:53:26     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:53:26     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:53:26     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:53:26     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:53:26     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:53:26     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:53:27 GET 304 https://storycraft-125188993477.us-central1.run.app/placeholder.svg
# 2025-01-23 21:53:10 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 7)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 4)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 2)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 3)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 6)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:39 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:54:54 Error generating image: TypeError: Cannot read properties of undefined (reading '0')
# 2025-01-23 21:54:54     at /app/.next/server/app/page.js:23:829
# 2025-01-23 21:54:54     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:54:54     at async Promise.all (index 5)
# 2025-01-23 21:54:54     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:54:54     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:54:54     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:54:54     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:54:54     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:54:54     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:54:54     at async NextNodeServer.renderToResponseWithComponentsImpl (/app/node_modules/next/dist/server/base-server.js:1482:28)
# 2025-01-23 21:54:55 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 21:54:56 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 21:55:15 Generating video...
# 2025-01-23 21:55:15 Generating video for scene 1
# 2025-01-23 21:55:16 operationName: projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/c4408b75-b610-4430-a519-997b21ebc6cf
# 2025-01-23 21:57:13 Successfully generated video for scene 1
# 2025-01-23 21:57:13 {
# 2025-01-23 21:57:13   name: 'projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/c4408b75-b610-4430-a519-997b21ebc6cf',
# 2025-01-23 21:57:13   done: true,
# 2025-01-23 21:57:13   response: {
# 2025-01-23 21:57:13     '@type': 'type.googleapis.com/cloud.ai.large_models.vision.GenerateVideoResponse',
# 2025-01-23 21:57:13     generatedSamples: [ [Object] ]
# 2025-01-23 21:57:13   }
# 2025-01-23 21:57:13 }
# 2025-01-23 21:57:13 Generating tts for scene 1
# 2025-01-23 21:57:14 Audio content written to file: /tmp/tts/audio-85722ea8-133b-4c8d-89dd-ba2dccdfa2f1.mp3
# 2025-01-23 21:57:14 Concatenate all videos
# 2025-01-23 21:57:14 Download all videos
# 2025-01-23 21:57:14 Concatenate videos using FFmpeg
# 2025-01-23 21:55:15 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:57:17 Adding music
# 2025-01-23 21:57:17 Successfully added audio to video with fade-out!
# 2025-01-23 21:57:17 Adding voiceover
# 2025-01-23 21:57:17 FFmpeg command: ffmpeg -i /tmp/video-concat-adlekF/c7b2410b-de13-498d-bcbc-22ff6e8df4fb_with_audio.mp4 -i /tmp/tts/audio-85722ea8-133b-4c8d-89dd-ba2dccdfa2f1.mp3 -y -filter_complex [0:a]volume=enable='between(t,0,1.368)':volume=0.3[v0];[1:a]adelay=0s|0s,apad=whole_dur=6[a0];[v0][a0]amix=inputs=2:duration=first:dropout_transition=2[mix0] -map [mix0] -map 0:v -c:v copy -y /tmp/video-concat-adlekF/c7b2410b-de13-498d-bcbc-22ff6e8df4fb_with_voiceover.mp4
# 2025-01-23 21:57:18 Voiceover added successfully!
# 2025-01-23 21:57:18 Upload result to GCS
# 2025-01-23 21:57:18 url: https://storage.googleapis.com/svc-demo-vertex-us/c7b2410b-de13-498d-bcbc-22ff6e8df4fb.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T215718Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 21:57:18 url: https://storage.googleapis.com/svc-demo-vertex-us/c7b2410b-de13-498d-bcbc-22ff6e8df4fb.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T215718Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 21:57:18 Generated video!
# 2025-01-23 21:57:26 GET 200 https://storycraft-125188993477.us-central1.run.app/favicon.ico
# 2025-01-23 21:57:27 GET 200 https://storycraft-125188993477.us-central1.run.app/favicon.ico
# 2025-01-23 21:57:27 GET 200 https://storycraft-125188993477.us-central1.run.app/favicon.ico
# 2025-01-23 21:58:53 Error generating image: Error: HTTP error! status: 500
# 2025-01-23 21:58:53     at c (/app/.next/server/app/page.js:13:134874)
# 2025-01-23 21:58:53     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
# 2025-01-23 21:58:53     at async /app/.next/server/app/page.js:23:748
# 2025-01-23 21:58:53     at async Promise.all (index 0)
# 2025-01-23 21:58:53     at async h (/app/.next/server/app/page.js:23:704)
# 2025-01-23 21:58:53     at async /app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:16:418
# 2025-01-23 21:58:53     at async rE (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:15:8148)
# 2025-01-23 21:58:53     at async r7 (/app/node_modules/next/dist/compiled/next-server/app-page.runtime.prod.js:18:1144)
# 2025-01-23 21:58:53     at async doRender (/app/node_modules/next/dist/server/base-server.js:1413:30)
# 2025-01-23 21:58:53     at async cacheEntry.responseCache.get.routeKind (/app/node_modules/next/dist/server/base-server.js:1574:28)
# 2025-01-23 21:59:02 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 21:59:02 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 21:58:48 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 21:59:06 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 21:59:07 GET 304 https://storycraft-125188993477.us-central1.run.app/placeholder.svg
# 2025-01-23 22:00:11 Regenerating image with prompt: Cinematic photorealistic shot. A man's hand, meticulously groomed, holds a Gillette razor.  The razor is gleaming, reflecting light.  The background is a blurred, luxurious bathroom with steam rising from a hot shower.  Focus sharply on the razor and hand.  Lighting: soft, warm, emphasizing the metallic sheen of the razor.  Style: reminiscent of a high-end cologne commercial.
# 2025-01-23 22:00:11 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22
# 2025-01-23 22:02:44 Audio content written to file: /tmp/tts/audio-9585cb3c-c629-4a87-83f4-6d64b05d8ba2.mp3
# 2025-01-23 22:02:44 Concatenate all videos
# 2025-01-23 22:02:44 Download all videos
# 2025-01-23 22:02:45 Concatenate videos using FFmpeg
# 2025-01-23 22:02:45 Adding music
# 2025-01-23 22:02:46 Successfully added audio to video with fade-out!
# 2025-01-23 22:02:46 Adding voiceover
# 2025-01-23 22:00:28 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:02:47 FFmpeg command: ffmpeg -i /tmp/video-concat-IpoPoI/b1a23b24-8929-4f6f-ab9d-317688457a47_with_audio.mp4 -i /tmp/tts/audio-24642ab7-3117-460c-abe8-c1bb63115b0b.mp3 -i /tmp/tts/audio-a4b71573-7df1-42e0-a1fc-23fb7a83c352.mp3 -i /tmp/tts/audio-732e23f3-0210-4dcb-9ac0-d85857c958fe.mp3 -i /tmp/tts/audio-9585cb3c-c629-4a87-83f4-6d64b05d8ba2.mp3 -y -filter_complex [0:a]volume=enable='between(t,0,1.224)':volume=0.3[v0];[1:a]adelay=0s|0s,apad=whole_dur=6[a0];[v0][a0]amix=inputs=2:duration=first:dropout_transition=2[mix0];[mix0]volume=enable='between(t,6,7.176)':volume=0.3[v1];[2:a]adelay=6s|6s,apad=whole_dur=6[a1];[v1][a1]amix=inputs=2:duration=first:dropout_transition=2[mix1];[mix1]volume=enable='between(t,12,13.704)':volume=0.3[v2];[3:a]adelay=12s|12s,apad=whole_dur=6[a2];[v2][a2]amix=inputs=2:duration=first:dropout_transition=2[mix2];[mix2]volume=enable='between(t,18,20.568)':volume=0.3[v3];[4:a]adelay=18s|18s,apad=whole_dur=6[a3];[v3][a3]amix=inputs=2:duration=first:dropout_transition=2[mix3] -map [mix3] -map 0:v -c:v copy -y /tmp/video-concat-IpoPoI/b1a23b24-8929-4f6f-ab9d-317688457a47_with_voiceover.mp4
# 2025-01-23 22:02:48 Voiceover added successfully!
# 2025-01-23 22:02:48 Upload result to GCS
# 2025-01-23 22:02:48 url: https://storage.googleapis.com/svc-demo-vertex-us/b1a23b24-8929-4f6f-ab9d-317688457a47.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T220248Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 22:02:48 url: https://storage.googleapis.com/svc-demo-vertex-us/b1a23b24-8929-4f6f-ab9d-317688457a47.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T220248Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 22:02:48 Generated video!
# 2025-01-23 22:04:09 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:04:09 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:04:19 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:04:38 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:04:38 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:04:51 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:04:54 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:04:54 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:05:04 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:05:09 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:05:09 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:05:19 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:05:23 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:05:23 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:05:32 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:05:42 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:05:42 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:05:52 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-23 22:05:56 Regenerating image with prompt: Cinematic photorealistic shot. A man with a strong jawline and short, perfectly groomed beard is shaving with a Gillette razor.  The scene is set in a modern, minimalist bathroom with natural light streaming in from a large window.  The man's expression is one of calm confidence.  Focus on the smooth, even shave.  Lighting: natural, bright, highlighting the clean lines of his face.  Style: aspirational, sophisticated.
# 2025-01-23 22:05:56 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22
# 2025-01-23 22:24:11 Generating tts for scene 3
# 2025-01-23 22:24:11 Generating tts for scene 4
# 2025-01-23 22:24:12 Audio content written to file: /tmp/tts/audio-517812c8-e5ab-4dbf-a2a1-5a0fbfd9c7a9.mp3
# 2025-01-23 22:24:12 Audio content written to file: /tmp/tts/audio-e81a17c1-4a98-467e-b1a7-3a1197d8827c.mp3
# 2025-01-23 22:24:12 Audio content written to file: /tmp/tts/audio-6bdf3a6a-e844-4347-ac52-90f8325ef1b4.mp3
# 2025-01-23 22:24:12 Audio content written to file: /tmp/tts/audio-f1ddeec1-faa8-430f-9f1d-2cbdac99aae0.mp3
# 2025-01-23 22:24:12 Concatenate all videos
# 2025-01-23 22:24:12 Download all videos
# 2025-01-23 22:24:13 Concatenate videos using FFmpeg
# 2025-01-23 22:24:15 Adding music
# 2025-01-23 22:24:16 Successfully added audio to video with fade-out!
# 2025-01-23 22:24:16 Adding voiceover
# 2025-01-23 22:21:48 POST 200 https://storycraft-125188993477.us-central1.run.app/
# 2025-01-23 22:24:16 FFmpeg command: ffmpeg -i /tmp/video-concat-HClIOn/58820a81-3f65-470d-88df-30a3c99a3aa1_with_audio.mp4 -i /tmp/tts/audio-6bdf3a6a-e844-4347-ac52-90f8325ef1b4.mp3 -i /tmp/tts/audio-517812c8-e5ab-4dbf-a2a1-5a0fbfd9c7a9.mp3 -i /tmp/tts/audio-e81a17c1-4a98-467e-b1a7-3a1197d8827c.mp3 -i /tmp/tts/audio-f1ddeec1-faa8-430f-9f1d-2cbdac99aae0.mp3 -y -filter_complex [0:a]volume=enable='between(t,0,1.176)':volume=0.3[v0];[1:a]adelay=0s|0s,apad=whole_dur=6[a0];[v0][a0]amix=inputs=2:duration=first:dropout_transition=2[mix0];[mix0]volume=enable='between(t,6,7.296)':volume=0.3[v1];[2:a]adelay=6s|6s,apad=whole_dur=6[a1];[v1][a1]amix=inputs=2:duration=first:dropout_transition=2[mix1];[mix1]volume=enable='between(t,12,13.488)':volume=0.3[v2];[3:a]adelay=12s|12s,apad=whole_dur=6[a2];[v2][a2]amix=inputs=2:duration=first:dropout_transition=2[mix2];[mix2]volume=enable='between(t,18,20.568)':volume=0.3[v3];[4:a]adelay=18s|18s,apad=whole_dur=6[a3];[v3][a3]amix=inputs=2:duration=first:dropout_transition=2[mix3] -map [mix3] -map 0:v -c:v copy -y /tmp/video-concat-HClIOn/58820a81-3f65-470d-88df-30a3c99a3aa1_with_voiceover.mp4
# 2025-01-23 22:24:17 Voiceover added successfully!
# 2025-01-23 22:24:17 Upload result to GCS
# 2025-01-23 22:24:18 url: https://storage.googleapis.com/svc-demo-vertex-us/58820a81-3f65-470d-88df-30a3c99a3aa1.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T222418Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 22:24:18 url: https://storage.googleapis.com/svc-demo-vertex-us/58820a81-3f65-470d-88df-30a3c99a3aa1.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250123%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250123T222418Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-23 22:24:18 Generated video!
