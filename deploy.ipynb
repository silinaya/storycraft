# %%
PROJECT_ID = "cloud-llm-preview1"
REGION = "us-central1"
BUCKET_NAME = "gs://mb-cloud-llm-preview1-bucket/img2vid"
SERVICE="storycraft"

# %%
# Set the IMAGE_URI
IMAGE_URI=f"us-central1-docker.pkg.dev/{PROJECT_ID}/mb-test/{SERVICE}:v1"

# %%
! docker build -f ./Dockerfile -t $IMAGE_URI .
# Out:
# Sending build context to Docker daemon  7.052MB
# Step 1/30 : FROM node:23-alpine AS base
# 23-alpine: Pulling from library/node
#
# 46996e29: Pulling fs layer
# 1c4031ef: Pulling fs layer
# f81bb5d5: Pulling fs layer
# Digest: sha256:15b885c5e195296ba49bab32681b478e92eb0f255078a84ad29020b87b0bdcc6[3A
# Status: Downloaded newer image for node:23-alpine
#  ---> a38495a0187e
# Step 2/30 : FROM base AS deps
#  ---> a38495a0187e
# Step 3/30 : RUN apk add --update libc6-compat
#  ---> Running in 64f18ce62194
# fetch https://dl-cdn.alpinelinux.org/alpine/v3.21/main/x86_64/APKINDEX.tar.gz
# fetch https://dl-cdn.alpinelinux.org/alpine/v3.21/community/x86_64/APKINDEX.tar.gz
# (1/3) Installing musl-obstack (1.2.3-r2)
# (2/3) Installing libucontext (1.3.2-r0)
# (3/3) Installing gcompat (1.1.0-r4)
# OK: 10 MiB in 20 packages
# Removing intermediate container 64f18ce62194
#  ---> a5c87a3ece25
# Step 4/30 : RUN apk add --update ffmpeg
#  ---> Running in 5bac10b84106
# (1/109) Installing libSvtAv1Enc (2.2.1-r0)
# (2/109) Installing aom-libs (3.11.0-r0)
# (3/109) Installing libxau (1.0.11-r4)
# (4/109) Installing libmd (1.1.0-r0)
# (5/109) Installing libbsd (0.12.2-r0)
# (6/109) Installing libxdmcp (1.1.5-r1)
# (7/109) Installing libxcb (1.16.1-r0)
# (8/109) Installing libx11 (1.8.10-r0)
# (9/109) Installing hwdata-pci (0.390-r0)
# (10/109) Installing libpciaccess (0.18.1-r0)
# (11/109) Installing libdrm (2.4.123-r1)
# (12/109) Installing libxext (1.3.6-r2)
# (13/109) Installing libxfixes (6.0.1-r4)
# (14/109) Installing libffi (3.4.6-r0)
# (15/109) Installing wayland-libs-client (1.23.1-r0)
# (16/109) Installing libva (2.22.0-r1)
# (17/109) Installing libvdpau (1.5-r4)
# (18/109) Installing onevpl-libs (2023.3.1-r2)
# (19/109) Installing ffmpeg-libavutil (6.1.2-r1)
# (20/109) Installing libdav1d (1.5.0-r0)
# (21/109) Installing openexr-libiex (3.3.2-r0)
# (22/109) Installing openexr-libilmthread (3.3.2-r0)
# (23/109) Installing imath (3.1.12-r0)
# (24/109) Installing libdeflate (1.22-r0)
# (25/109) Installing openexr-libopenexrcore (3.3.2-r0)
# (26/109) Installing openexr-libopenexr (3.3.2-r0)
# (27/109) Installing brotli-libs (1.1.0-r2)
# (28/109) Installing giflib (5.2.2-r0)
# (29/109) Installing libhwy (1.0.7-r0)
# (30/109) Installing libjpeg-turbo (3.0.4-r0)
# (31/109) Installing lcms2 (2.16-r0)
# (32/109) Installing libpng (1.6.44-r0)
# (33/109) Installing libjxl (0.10.3-r0)
# (34/109) Installing lame-libs (3.100-r5)
# (35/109) Installing opus (1.5.2-r1)
# (36/109) Installing rav1e-libs (0.7.1-r0)
# (37/109) Installing libgomp (14.2.0-r4)
# (38/109) Installing soxr (0.1.3-r7)
# (39/109) Installing ffmpeg-libswresample (6.1.2-r1)
# (40/109) Installing libogg (1.3.5-r5)
# (41/109) Installing libtheora (1.1.1-r18)
# (42/109) Installing libvorbis (1.3.7-r2)
# (43/109) Installing libvpx (1.15.0-r0)
# (44/109) Installing libsharpyuv (1.4.0-r0)
# (45/109) Installing libwebp (1.4.0-r0)
# (46/109) Installing libwebpmux (1.4.0-r0)
# (47/109) Installing x264-libs (0.164.3108-r0)
# (48/109) Installing numactl (2.0.18-r0)
# (49/109) Installing x265-libs (3.6-r0)
# (50/109) Installing xvidcore (1.3.7-r2)
# (51/109) Installing ffmpeg-libavcodec (6.1.2-r1)
# (52/109) Installing sdl2 (2.30.9-r0)
# (53/109) Installing alsa-lib (1.2.12-r0)
# (54/109) Installing libexpat (2.6.4-r0)
# (55/109) Installing libbz2 (1.0.8-r6)
# (56/109) Installing freetype (2.13.3-r0)
# (57/109) Installing fontconfig (2.15.0-r1)
# (58/109) Installing fribidi (1.0.16-r0)
# (59/109) Installing libintl (0.22.5-r0)
# (60/109) Installing libeconf (0.6.3-r0)
# (61/109) Installing libblkid (2.40.4-r0)
# (62/109) Installing libmount (2.40.4-r0)
# (63/109) Installing pcre2 (10.43-r0)
# (64/109) Installing glib (2.82.4-r0)
# (65/109) Installing graphite2 (1.3.14-r6)
# (66/109) Installing harfbuzz (9.0.0-r1)
# (67/109) Installing libunibreak (6.1-r0)
# (68/109) Installing libass (0.17.3-r0)
# (69/109) Installing libbluray (1.3.4-r1)
# (70/109) Installing mpg123-libs (1.32.9-r0)
# (71/109) Installing libopenmpt (0.7.12-r0)
# (72/109) Installing cjson (1.7.18-r0)
# (73/109) Installing mbedtls (3.6.2-r0)
# (74/109) Installing librist (0.2.10-r1)
# (75/109) Installing libsrt (1.5.3-r0)
# (76/109) Installing libssh (0.11.1-r0)
# (77/109) Installing xz-libs (5.6.3-r0)
# (78/109) Installing libxml2 (2.13.4-r3)
# (79/109) Installing libsodium (1.0.20-r0)
# (80/109) Installing libzmq (4.3.5-r2)
# (81/109) Installing ffmpeg-libavformat (6.1.2-r1)
# (82/109) Installing serd-libs (0.32.2-r0)
# (83/109) Installing zix-libs (0.4.2-r0)
# (84/109) Installing sord-libs (0.16.16-r0)
# (85/109) Installing sratom (0.6.16-r0)
# (86/109) Installing lilv-libs (0.24.24-r1)
# (87/109) Installing libdovi (3.3.1-r0)
# (88/109) Installing spirv-tools (1.3.290.0-r0)
# (89/109) Installing glslang-libs (1.3.296.0-r0)
# (90/109) Installing shaderc (2024.0-r2)
# (91/109) Installing vulkan-loader (1.3.296.0-r0)
# (92/109) Installing libplacebo (6.338.2-r3)
# (93/109) Installing ffmpeg-libpostproc (6.1.2-r1)
# (94/109) Installing ffmpeg-libswscale (6.1.2-r1)
# (95/109) Installing vidstab (1.1.1-r0)
# (96/109) Installing zimg (3.0.5-r2)
# (97/109) Installing ffmpeg-libavfilter (6.1.2-r1)
# (98/109) Installing libasyncns (0.8-r4)
# (99/109) Installing dbus-libs (1.14.10-r4)
# (100/109) Installing libltdl (2.4.7-r3)
# (101/109) Installing orc (0.4.40-r1)
# (102/109) Installing libflac (1.4.3-r1)
# (103/109) Installing libsndfile (1.2.2-r2)
# (104/109) Installing speexdsp (1.2.1-r2)
# (105/109) Installing tdb-libs (1.4.12-r0)
# (106/109) Installing libpulse (17.0-r4)
# (107/109) Installing v4l-utils-libs (1.28.1-r1)
# (108/109) Installing ffmpeg-libavdevice (6.1.2-r1)
# (109/109) Installing ffmpeg (6.1.2-r1)
# Executing busybox-1.37.0-r9.trigger
# Executing glib-2.82.4-r0.trigger
# OK: 129 MiB in 129 packages
# Removing intermediate container 5bac10b84106
#  ---> 089b51e225e2
# Step 5/30 : WORKDIR /app
#  ---> Running in d979f6dd47eb
# Removing intermediate container d979f6dd47eb
#  ---> 832251f8f469
# Step 6/30 : COPY package.json yarn.lock* package-lock.json* pnpm-lock.yaml* ./
#  ---> 57a09c06e053
# Step 7/30 : RUN   if [ -f yarn.lock ]; then yarn --frozen-lockfile;   elif [ -f package-lock.json ]; then npm ci;   elif [ -f pnpm-lock.yaml ]; then yarn global add pnpm && pnpm i --frozen-lockfile;   else echo "Lockfile not found." && exit 1;   fi
#  ---> Running in 0ec25c0ad9ca
# npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# npm warn deprecated @humanwhocodes/object-schema@2.0.3: Use @eslint/object-schema instead
# npm warn deprecated @humanwhocodes/config-array@0.13.0: Use @eslint/config-array instead
# npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# npm warn deprecated eslint@8.57.1: This version is no longer supported. Please see https://eslint.org/version-support for other options.
#
# added 530 packages, and audited 531 packages in 18s
#
# 158 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues, run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New major version of npm available! 10.9.2 -> 11.1.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.1.0
# npm notice To update run: npm install -g npm@11.1.0
# npm notice
# Removing intermediate container 0ec25c0ad9ca
#  ---> 7b5f24406203
# Step 8/30 : FROM base AS builder
#  ---> a38495a0187e
# Step 9/30 : WORKDIR /app
#  ---> Running in 76e300a08e9a
# Removing intermediate container 76e300a08e9a
#  ---> 9ff847596373
# Step 10/30 : COPY --from=deps /app/node_modules ./node_modules
#  ---> c9c46579f730
# Step 11/30 : COPY . .
#  ---> 74d48819bfe8
# Step 12/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Running in 2f3572ef5f87
# Removing intermediate container 2f3572ef5f87
#  ---> 315e122f3925
# Step 13/30 : RUN yarn build
#  ---> Running in fa8596ef9924
# yarn run v1.22.22
# $ next build
#   ▲ Next.js 14.2.16
#
#    Creating an optimized production build ...
# (node:40) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:78) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#  ✓ Compiled successfully
#    Linting and checking validity of types ...
#    Collecting page data ...
# (node:135) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#    Generating static pages (0/7) ...
#    Generating static pages (1/7)
#    Generating static pages (3/7)
#    Generating static pages (5/7)
# Component rendered
# (node:136) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#  ✓ Generating static pages (7/7)
#    Finalizing page optimization ...
#    Collecting build traces ...
#
# Route (app)                              Size     First Load JS
# ┌ ○ /                                    65.3 kB         152 kB
# ├ ○ /_not-found                          873 B            88 kB
# ├ ƒ /api/scene                           0 B                0 B
# └ ƒ /api/videos                          0 B                0 B
# + First Load JS shared by all            87.1 kB
#   ├ chunks/117-a6603f03b208d3bf.js       31.6 kB
#   ├ chunks/fd9d1056-796f5f0836d7e441.js  53.6 kB
#   └ other shared chunks (total)          1.9 kB
#
#
# ○  (Static)   prerendered as static content
# ƒ  (Dynamic)  server-rendered on demand
#
# Done in 64.33s.
# Removing intermediate container fa8596ef9924
#  ---> ac0ff88e1de6
# Step 14/30 : FROM base AS runner
#  ---> a38495a0187e
# Step 15/30 : RUN apk add --update ffmpeg
#  ---> Running in 332b0e212d47
# fetch https://dl-cdn.alpinelinux.org/alpine/v3.21/main/x86_64/APKINDEX.tar.gz
# fetch https://dl-cdn.alpinelinux.org/alpine/v3.21/community/x86_64/APKINDEX.tar.gz
# (1/109) Installing libSvtAv1Enc (2.2.1-r0)
# (2/109) Installing aom-libs (3.11.0-r0)
# (3/109) Installing libxau (1.0.11-r4)
# (4/109) Installing libmd (1.1.0-r0)
# (5/109) Installing libbsd (0.12.2-r0)
# (6/109) Installing libxdmcp (1.1.5-r1)
# (7/109) Installing libxcb (1.16.1-r0)
# (8/109) Installing libx11 (1.8.10-r0)
# (9/109) Installing hwdata-pci (0.390-r0)
# (10/109) Installing libpciaccess (0.18.1-r0)
# (11/109) Installing libdrm (2.4.123-r1)
# (12/109) Installing libxext (1.3.6-r2)
# (13/109) Installing libxfixes (6.0.1-r4)
# (14/109) Installing libffi (3.4.6-r0)
# (15/109) Installing wayland-libs-client (1.23.1-r0)
# (16/109) Installing libva (2.22.0-r1)
# (17/109) Installing libvdpau (1.5-r4)
# (18/109) Installing onevpl-libs (2023.3.1-r2)
# (19/109) Installing ffmpeg-libavutil (6.1.2-r1)
# (20/109) Installing libdav1d (1.5.0-r0)
# (21/109) Installing openexr-libiex (3.3.2-r0)
# (22/109) Installing openexr-libilmthread (3.3.2-r0)
# (23/109) Installing imath (3.1.12-r0)
# (24/109) Installing libdeflate (1.22-r0)
# (25/109) Installing openexr-libopenexrcore (3.3.2-r0)
# (26/109) Installing openexr-libopenexr (3.3.2-r0)
# (27/109) Installing brotli-libs (1.1.0-r2)
# (28/109) Installing giflib (5.2.2-r0)
# (29/109) Installing libhwy (1.0.7-r0)
# (30/109) Installing libjpeg-turbo (3.0.4-r0)
# (31/109) Installing lcms2 (2.16-r0)
# (32/109) Installing libpng (1.6.44-r0)
# (33/109) Installing libjxl (0.10.3-r0)
# (34/109) Installing lame-libs (3.100-r5)
# (35/109) Installing opus (1.5.2-r1)
# (36/109) Installing rav1e-libs (0.7.1-r0)
# (37/109) Installing libgomp (14.2.0-r4)
# (38/109) Installing soxr (0.1.3-r7)
# (39/109) Installing ffmpeg-libswresample (6.1.2-r1)
# (40/109) Installing libogg (1.3.5-r5)
# (41/109) Installing libtheora (1.1.1-r18)
# (42/109) Installing libvorbis (1.3.7-r2)
# (43/109) Installing libvpx (1.15.0-r0)
# (44/109) Installing libsharpyuv (1.4.0-r0)
# (45/109) Installing libwebp (1.4.0-r0)
# (46/109) Installing libwebpmux (1.4.0-r0)
# (47/109) Installing x264-libs (0.164.3108-r0)
# (48/109) Installing numactl (2.0.18-r0)
# (49/109) Installing x265-libs (3.6-r0)
# (50/109) Installing xvidcore (1.3.7-r2)
# (51/109) Installing ffmpeg-libavcodec (6.1.2-r1)
# (52/109) Installing sdl2 (2.30.9-r0)
# (53/109) Installing alsa-lib (1.2.12-r0)
# (54/109) Installing libexpat (2.6.4-r0)
# (55/109) Installing libbz2 (1.0.8-r6)
# (56/109) Installing freetype (2.13.3-r0)
# (57/109) Installing fontconfig (2.15.0-r1)
# (58/109) Installing fribidi (1.0.16-r0)
# (59/109) Installing libintl (0.22.5-r0)
# (60/109) Installing libeconf (0.6.3-r0)
# (61/109) Installing libblkid (2.40.4-r0)
# (62/109) Installing libmount (2.40.4-r0)
# (63/109) Installing pcre2 (10.43-r0)
# (64/109) Installing glib (2.82.4-r0)
# (65/109) Installing graphite2 (1.3.14-r6)
# (66/109) Installing harfbuzz (9.0.0-r1)
# (67/109) Installing libunibreak (6.1-r0)
# (68/109) Installing libass (0.17.3-r0)
# (69/109) Installing libbluray (1.3.4-r1)
# (70/109) Installing mpg123-libs (1.32.9-r0)
# (71/109) Installing libopenmpt (0.7.12-r0)
# (72/109) Installing cjson (1.7.18-r0)
# (73/109) Installing mbedtls (3.6.2-r0)
# (74/109) Installing librist (0.2.10-r1)
# (75/109) Installing libsrt (1.5.3-r0)
# (76/109) Installing libssh (0.11.1-r0)
# (77/109) Installing xz-libs (5.6.3-r0)
# (78/109) Installing libxml2 (2.13.4-r3)
# (79/109) Installing libsodium (1.0.20-r0)
# (80/109) Installing libzmq (4.3.5-r2)
# (81/109) Installing ffmpeg-libavformat (6.1.2-r1)
# (82/109) Installing serd-libs (0.32.2-r0)
# (83/109) Installing zix-libs (0.4.2-r0)
# (84/109) Installing sord-libs (0.16.16-r0)
# (85/109) Installing sratom (0.6.16-r0)
# (86/109) Installing lilv-libs (0.24.24-r1)
# (87/109) Installing libdovi (3.3.1-r0)
# (88/109) Installing spirv-tools (1.3.290.0-r0)
# (89/109) Installing glslang-libs (1.3.296.0-r0)
# (90/109) Installing shaderc (2024.0-r2)
# (91/109) Installing vulkan-loader (1.3.296.0-r0)
# (92/109) Installing libplacebo (6.338.2-r3)
# (93/109) Installing ffmpeg-libpostproc (6.1.2-r1)
# (94/109) Installing ffmpeg-libswscale (6.1.2-r1)
# (95/109) Installing vidstab (1.1.1-r0)
# (96/109) Installing zimg (3.0.5-r2)
# (97/109) Installing ffmpeg-libavfilter (6.1.2-r1)
# (98/109) Installing libasyncns (0.8-r4)
# (99/109) Installing dbus-libs (1.14.10-r4)
# (100/109) Installing libltdl (2.4.7-r3)
# (101/109) Installing orc (0.4.40-r1)
# (102/109) Installing libflac (1.4.3-r1)
# (103/109) Installing libsndfile (1.2.2-r2)
# (104/109) Installing speexdsp (1.2.1-r2)
# (105/109) Installing tdb-libs (1.4.12-r0)
# (106/109) Installing libpulse (17.0-r4)
# (107/109) Installing v4l-utils-libs (1.28.1-r1)
# (108/109) Installing ffmpeg-libavdevice (6.1.2-r1)
# (109/109) Installing ffmpeg (6.1.2-r1)
# Executing busybox-1.37.0-r9.trigger
# Executing glib-2.82.4-r0.trigger
# OK: 128 MiB in 126 packages
# Removing intermediate container 332b0e212d47
#  ---> 7cce560d2ff7
# Step 16/30 : WORKDIR /app
#  ---> Running in a105556b25f0
# Removing intermediate container a105556b25f0
#  ---> c30a3a9b3d2d
# Step 17/30 : ENV NODE_ENV production
#  ---> Running in d64177f4beed
# Removing intermediate container d64177f4beed
#  ---> e210054fd5af
# Step 18/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Running in 6893a583c425
# Removing intermediate container 6893a583c425
#  ---> 7068f6a50dd2
# Step 19/30 : RUN addgroup --system --gid 1001 nodejs
#  ---> Running in e06bc9990004
# Removing intermediate container e06bc9990004
#  ---> 99f88fda0f55
# Step 20/30 : RUN adduser --system --uid 1001 nextjs
#  ---> Running in fed67f8296fc
# Removing intermediate container fed67f8296fc
#  ---> 5dc227073345
# Step 21/30 : COPY --from=builder /app/public ./public
#  ---> 689b27360e8f
# Step 22/30 : RUN mkdir .next
#  ---> Running in a94398489a1b
# Removing intermediate container a94398489a1b
#  ---> 9132291f6657
# Step 23/30 : RUN chown nextjs:nodejs .next
#  ---> Running in 71d6c83e0e49
# Removing intermediate container 71d6c83e0e49
#  ---> a4e81ad70bd3
# Step 24/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/standalone ./
#  ---> 75e19e63d8ac
# Step 25/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/static ./.next/static
#  ---> 6a27ac13dec8
# Step 26/30 : USER nextjs
#  ---> Running in db44731f6dea
# Removing intermediate container db44731f6dea
#  ---> 538b4595ac49
# Step 27/30 : EXPOSE 3000
#  ---> Running in 1efb9d424818
# Removing intermediate container 1efb9d424818
#  ---> 8c67ad1f97ea
# Step 28/30 : ENV PORT 3000
#  ---> Running in 6441265e6154
# Removing intermediate container 6441265e6154
#  ---> 521a66349a4f
# Step 29/30 : ENV HOSTNAME "0.0.0.0"
#  ---> Running in d52bc0376da6
# Removing intermediate container d52bc0376da6
#  ---> 0074513e7fdf
# Step 30/30 : CMD ["node", "server.js"]
#  ---> Running in 59143131ebe7
# Removing intermediate container 59143131ebe7
#  ---> 540ce27458f1
# Successfully built 540ce27458f1
# Successfully tagged us-central1-docker.pkg.dev/cloud-llm-preview1/mb-test/storycraft:v1

# %%
! docker push $IMAGE_URI
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/cloud-llm-preview1/mb-test/storycraft]
#
# 1be16f26: Preparing
# 3709d1ad: Preparing
# 91b29b27: Preparing
# f939d06d: Preparing
# 2d27037d: Preparing
# 91a18fd4: Preparing
# 163ee53c: Preparing
# 8557f45c: Preparing
# 5c27c073: Preparing
# 2ff1e123: Preparing
# d6b1ae9a: Preparing
# 3123ac33: Preparing
# 3123ac33: Pushed   150.5MB/147.8MBv1: digest: sha256:bb9c230ca898c4c192d93fd66c2e707af76ae09e28f66db319db2362ba40edbb size: 3039

# %%
# %%capture capt
! gcloud run deploy $SERVICE --image $IMAGE_URI --region $REGION --cpu 2

# %%
print(capt.stderr)

# %%
! gcloud beta run services logs tail $SERVICE --project $PROJECT_ID --region $REGION
# Out:
# streaming logs from cloud-llm-preview1
# 2025-01-30 21:08:28  ✓ Ready in 18.8s
