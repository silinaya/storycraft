# %%
PROJECT_ID = "svc-demo-vertex"
REGION = "us-central1"
BUCKET_NAME = "gs://svc-demo-vertex-us"
SERVICE="storycraft"

# %%
# Set the IMAGE_URI
IMAGE_URI=f"us-central1-docker.pkg.dev/{PROJECT_ID}/vertexai/{SERVICE}:v1"

# %%
! docker build -f ./Dockerfile -t $IMAGE_URI .
# Out:
# Sending build context to Docker daemon  476.2kB
# Step 1/30 : FROM node:23-alpine AS base
#  ---> 31d93c95bd30
# Step 2/30 : FROM base AS deps
#  ---> 31d93c95bd30
# Step 3/30 : RUN apk add --update libc6-compat
#  ---> Using cache
#  ---> 987e3ba7541d
# Step 4/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> aee0a0cdc1ac
# Step 5/30 : WORKDIR /app
#  ---> Using cache
#  ---> fcf22aff8751
# Step 6/30 : COPY package.json yarn.lock* package-lock.json* pnpm-lock.yaml* ./
#  ---> Using cache
#  ---> 69e2093c8283
# Step 7/30 : RUN   if [ -f yarn.lock ]; then yarn --frozen-lockfile;   elif [ -f package-lock.json ]; then npm ci;   elif [ -f pnpm-lock.yaml ]; then yarn global add pnpm && pnpm i --frozen-lockfile;   else echo "Lockfile not found." && exit 1;   fi
#  ---> Using cache
#  ---> 5ac26167cacf
# Step 8/30 : FROM base AS builder
#  ---> 31d93c95bd30
# Step 9/30 : WORKDIR /app
#  ---> Using cache
#  ---> 78cd07260f56
# Step 10/30 : COPY --from=deps /app/node_modules ./node_modules
#  ---> Using cache
#  ---> 5c7a43d57d12
# Step 11/30 : COPY . .
#  ---> Using cache
#  ---> 0b347abad28a
# Step 12/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Using cache
#  ---> 74ed192430df
# Step 13/30 : RUN yarn build
#  ---> Using cache
#  ---> abd9e774d918
# Step 14/30 : FROM base AS runner
#  ---> 31d93c95bd30
# Step 15/30 : RUN apk add --update ffmpeg
#  ---> Using cache
#  ---> 449c1d6b227f
# Step 16/30 : WORKDIR /app
#  ---> Using cache
#  ---> a00de02aa310
# Step 17/30 : ENV NODE_ENV production
#  ---> Using cache
#  ---> 71df020a905a
# Step 18/30 : ENV NEXT_TELEMETRY_DISABLED 1
#  ---> Using cache
#  ---> d2b2ef033973
# Step 19/30 : RUN addgroup --system --gid 1001 nodejs
#  ---> Using cache
#  ---> 398182075167
# Step 20/30 : RUN adduser --system --uid 1001 nextjs
#  ---> Using cache
#  ---> 599cdbe83371
# Step 21/30 : COPY --from=builder /app/public ./public
#  ---> Using cache
#  ---> 4d252d325524
# Step 22/30 : RUN mkdir .next
#  ---> Using cache
#  ---> 1c4b8ab70a88
# Step 23/30 : RUN chown nextjs:nodejs .next
#  ---> Using cache
#  ---> e18a10bb3d59
# Step 24/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/standalone ./
#  ---> Using cache
#  ---> 46324c6fbd89
# Step 25/30 : COPY --from=builder --chown=nextjs:nodejs /app/.next/static ./.next/static
#  ---> Using cache
#  ---> 8d4a33032cc6
# Step 26/30 : USER nextjs
#  ---> Using cache
#  ---> d2d5577fff4f
# Step 27/30 : EXPOSE 3000
#  ---> Using cache
#  ---> ec8f84ddab1e
# Step 28/30 : ENV PORT 3000
#  ---> Using cache
#  ---> 31dff3341c84
# Step 29/30 : ENV HOSTNAME "0.0.0.0"
#  ---> Using cache
#  ---> 726b36798ab5
# Step 30/30 : CMD ["node", "server.js"]
#  ---> Using cache
#  ---> 8115a9e548f8
# Successfully built 8115a9e548f8
# Successfully tagged us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft:v1

# %%
! docker push $IMAGE_URI
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/svc-demo-vertex/vertexai/storycraft]
#
# dd12cf5a: Preparing
# 3bb60f8c: Preparing
# cd99eb5f: Preparing
# 735f930f: Preparing
# f78bc1af: Preparing
# 78baf38f: Preparing
# 3ef1be29: Preparing
# c3228a59: Preparing
# fa0ec069: Preparing
# 1c5999de: Preparing
# 64ef9611: Preparing
# 842cb1dd: Preparing
# bb60f8c: Pushed   21.66MB/20.15MBv1: digest: sha256:6998ae5cbd633062a3be79364a6a9b4c5859f51c32e1707784c9280fe024018e size: 3035

# %%
! gcloud run deploy $SERVICE --image $IMAGE_URI --region $REGION
# Out:
# Deploying container to Cloud Run service [storycraft] in project [svc-demo-vertex] region [us-central1]
# Deploying...
#   . Creating Revision...
#   . Routing traffic...
#   Deploying...
#
#
# ⠛ Deploying...
#
#
# ⠹ Deploying...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
# ⠧ Deploying...
#   ⠧ Creating Revision...
#
# ⠏ Deploying... Deploying Revision.
#   ⠏ Creating Revision... Updating Service.
#
# ⠛ Deploying... Deploying Revision.
#   ⠛ Creating Revision... Updating Service.
#
# ⠹ Deploying... Deploying Revision.
#   ⠹ Creating Revision... Updating Service.
#
# ⠼ Deploying... Deploying Revision.
#   ⠼ Creating Revision... Updating Service.
#
# ⠶ Deploying... Deploying Revision.
#   ⠶ Creating Revision... Updating Service.
#
# ⠧ Deploying... Deploying Revision.
#   ⠧ Creating Revision... Updating Service.
#
# ⠏ Deploying... Deploying Revision.
#   ⠏ Creating Revision... Updating Service.
#
# ⠛ Deploying... Deploying Revision.
#   ⠛ Creating Revision... Updating Service.
#
# ⠹ Deploying... Deploying Revision.
#   ⠹ Creating Revision... Updating Service.
#
# ⠼ Deploying... Deploying Revision.
#   ⠼ Creating Revision... Updating Service.
#
# ⠶ Deploying... Deploying Revision.
#   ⠶ Creating Revision... Updating Service.
#
# ⠧ Deploying... Deploying Revision.
#   ⠧ Creating Revision... Updating Service.
#
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ⠏ Creating Revision... Updating Service.
#   ⠏ Routing traffic...
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ⠛ Creating Revision... Updating Service.
#   ⠛ Routing traffic...
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠹ Routing traffic...
# ⠼ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠶ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠧ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠹ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠼ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠶ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠧ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠏ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠛ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠹ Deploying... Container image import in progress. Imported 18 of 20 layers.
#
#
#   ⠹ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠼ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠶ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠧ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠏ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠛ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠹ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠹ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠼ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠼ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠶ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠶ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠧ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠧ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠏ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠏ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠛ Deploying... Provisioning revision instances to receive traffic.
#
#
#   ⠛ Routing traffic... Deploying Revision. Waiting on revision storycraft-00009
#   -s95.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Deploying Revision.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Deploying Revision.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Deploying Revision.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Deploying Revision.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Deploying Revision.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Deploying Revision.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Revision deployment finished in 1.62s. Checking container health
# .
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Assigning traffic to latest specified targets.
#   ✓ Creating Revision... Container image import in progress. Imported 18 of 20
#   layers.
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠹ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠼ Routing traffic... Provisioning revision instances to receive traffic.
# ⠶ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠶ Routing traffic... Provisioning revision instances to receive traffic.
# ⠧ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠧ Routing traffic... Provisioning revision instances to receive traffic.
# ⠏ Deploying... Assigning traffic to latest specified targets.
#
#
#   ⠏ Routing traffic... Provisioning revision instances to receive traffic.
# ⠛ Deploying...
#
#
#   ⠛ Routing traffic... Provisioning revision instances to receive traffic.
# ⠹ Deploying...
#
#
#   ✓ Routing traffic... Provisioning revision instances to receive traffic.
# ⠼ Deploying... Done.
#
#
#
# ⠶ Deploying... Done.
#
#
#
# ✓ Deploying... Done.
#
#
#
# Done.
# Service [storycraft] revision [storycraft-00009-s95] has been deployed and is serving 100 percent of traffic.
# Service URL: https://storycraft-idvt3gzwzq-uc.a.run.app

# %%
! gcloud beta run services logs tail $SERVICE --project $PROJECT_ID --region $REGION
# Out:
# streaming logs from svc-demo-vertex
# 2025-01-20 22:55:46  ✓ Ready in 10.6s
# 2025-01-20 22:55:57  ✓ Ready in 16s
# 2025-01-20 23:05:02 GET 200 https://storycraft-idvt3gzwzq-uc.a.run.app/
# 2025-01-20 23:05:03 GET 200 https://storycraft-idvt3gzwzq-uc.a.run.app/_next/static/chunks/app/page-0ec8f385b51a68e5.js
# 2025-01-20 23:05:15 (node:1) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# 2025-01-20 23:05:15 (Use `node --trace-deprecation ...` to show where the warning was created)
# 2025-01-20 23:05:30 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-20 23:05:15 POST 200 https://storycraft-idvt3gzwzq-uc.a.run.app/
# 2025-01-20 23:05:31 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-20 23:05:31 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-20 23:05:32 Generated image base64: iVBORw0KGgoAAAANSUhEUgAABYAAAAMACAIAAAASU1SbAAAAg3...
# 2025-01-20 23:05:45 Generating video...
# 2025-01-20 23:05:45 Generating video for scene 1
# 2025-01-20 23:05:45 Generating video for scene 2
# 2025-01-20 23:05:45 Generating video for scene 3
# 2025-01-20 23:05:45 Generating video for scene 4
# 2025-01-20 23:05:45 operationName: projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/1bf8cb7e-6c1c-492f-b3d6-9bf1f268f6f7
# 2025-01-20 23:05:46 operationName: projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/4c6e779b-1c50-4840-947b-3dcc63944862
# 2025-01-20 23:05:46 operationName: projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/0a5672a1-7399-4a0c-a73e-eb46add5a1a4
# 2025-01-20 23:05:46 operationName: projects/svc-demo-vertex/locations/us-central1/publishers/google/models/veo-001-preview-0815/operations/a7c4026d-8c79-4b3d-bb3c-46584b95a9f3
# 2025-01-20 23:07:49 Successfully generated video for scene 2
# 2025-01-20 23:08:00 Successfully generated video for scene 1
# 2025-01-20 23:08:04 Successfully generated video for scene 4
# 2025-01-20 23:08:06 Successfully generated video for scene 3
# 2025-01-20 23:08:06 Concatenate all videos
# 2025-01-20 23:08:06 Download all videos
# 2025-01-20 23:08:07 Concatenate videos using FFmpeg
# 2025-01-20 23:08:09 Upload result to GCS
# 2025-01-20 23:05:44 POST 200 https://storycraft-idvt3gzwzq-uc.a.run.app/
# 2025-01-20 23:08:10 url: https://storage.googleapis.com/svc-demo-vertex-us/9b594f20-cb46-447a-8049-058e239b7f2a.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250120%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250120T230810Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-20 23:08:10 url: https://storage.googleapis.com/svc-demo-vertex-us/9b594f20-cb46-447a-8049-058e239b7f2a.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=125188993477-compute%40developer.gserviceaccount.com%2F20250120%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250120T230810Z&X-Goog-Expires=3600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# 2025-01-20 23:08:10 Generated video!
